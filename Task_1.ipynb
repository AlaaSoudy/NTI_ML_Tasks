# %% [markdown]
# <a href="https://colab.research.google.com/github/AlaaSoudy/NTI_ML_Tasks/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/imports.csv')
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df.shape

# %%
mean_cols = [
    "normalized-losses",
    "bore",
    "stroke",
    "price",
    "horsepower",
    "peak-rpm"
]

for col in mean_cols:
    df[col] = df[col].fillna(df[col].mean())

df["num-of-doors"]=df["num-of-doors"].fillna(df["num-of-doors"].mode()[0])

# %%
df.shape

# %%
df

# %%
df.duplicated().sum()

# %%
numeric_df = df.select_dtypes(include='number')
axes = numeric_df.hist(figsize=(30, 15), bins=20)
for ax in axes.flatten():
    ax.tick_params(axis='x', rotation=90)
plt.tight_layout()
plt.show();

# %%
numeric_df = df.select_dtypes(include='number')

print(numeric_df.shape)

plt.figure(figsize=(15,8))
sns.boxplot(data=numeric_df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='num-of-doors')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df['price'] ,kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df['horsepower'] , kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
df.columns

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df['width'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df['horsepower'])
plt.xticks(rotation=90)
plt.show()

# %%
df.columns

# %%
df.groupby(['num-of-doors' ,'symboling' , 'stroke','city-mpg'])['price'].mean()

# %%
sns.scatterplot(data=df, x='horsepower' ,y='price', hue='price')
plt.xticks(rotation=90)
sns.regplot( data=df, x='horsepower', y='price', scatter=False, color='red')
plt.show()

# %%
cols_1=[ 'price' ,'horsepower','highway-mpg','city-mpg','stroke',
       'compression-ratio', 'peak-rpm', 'engine-size' ,
       'wheel-base', 'length', 'width', 'normalized-losses', 'bore', 'height']
for col_1 in cols_1:
 Q1 = df[col_1].quantile(0.25)
 Q3 = df[col_1].quantile(0.75)
 IQR = Q3 - Q1

 lower = Q1 - 1.5 * IQR
 upper = Q3 + 1.5 * IQR

 df[col_1] = df[col_1].clip(lower=lower, upper=upper)

# %%
df.shape

# %%
sns.boxplot(data=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
# print(f"Shape of DataFrame before outlier removal: {df.shape}")
# cols=[]
# # 'highway-mpg','city-mpg','stroke',
# #        'compression-ratio', 'peak-rpm', 'engine-size' ,
# #        'wheel-base', 'length', 'width', 'normalized-losses'

# for col in cols:
#     Q1 = df[col].quantile(0.25)
#     Q3 = df[col].quantile(0.75)
#     IQR = Q3 - Q1

#     lower = Q1 - 1.5 * IQR
#     upper = Q3 + 1.5 * IQR

#     before = df.shape[0]

#     df = df[(df[col] >= lower) & (df[col] <= upper)]

#     after = df.shape[0]

#     print(f"{col}: {before} -> {after}")

# print(f"Shape of DataFrame after outlier removal: {df.shape}")

# %%
df.columns

# %%
sns.boxplot(data=df['horsepower'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.boxenplot(df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(7,5))
# sns.pairplot(df , hue='price')
# plt.xticks(rotation=90)
# plt.show()

sns.boxplot(data=df['stroke'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.xticks(rotation=90)
plt.show()

# %%
df.columns

# %%
# df.drop('symboling', inplace=True, axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np
df = pd.get_dummies(df, drop_first=True)
X=df.drop('price', axis=1)
Y=df['price']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42 , shuffle=True)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
model=LinearRegression()
model.fit(X_train, Y_train)
Y_pred=model.predict(X_test)
print(f"Train R2: {model.score(X_train, Y_train)}")
print(f"Test R2: {r2_score( Y_test, Y_pred)}")
print(f"MAE: {mean_absolute_error(Y_test, Y_pred)}")
print(f"MSE: {mean_squared_error(Y_test, Y_pred)}")
print(f"RMSE: {np.sqrt(mean_squared_error(Y_test, Y_pred))}")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np
# df = pd.get_dummies(df, drop_first=True)
X=df[['horsepower']]
Y=df['price']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42 , shuffle=True)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
model=LinearRegression()
model.fit(X_train, Y_train)
Y_pred=model.predict(X_test)
print(f"Train R2: {model.score(X_train, Y_train)}")
print(f"Test R2: {r2_score( Y_test, Y_pred)}")
print(f"MAE: {mean_absolute_error(Y_test, Y_pred)}")
print(f"MSE: {mean_squared_error(Y_test, Y_pred)}")
print(f"RMSE: {np.sqrt(mean_squared_error(Y_test, Y_pred))}")
